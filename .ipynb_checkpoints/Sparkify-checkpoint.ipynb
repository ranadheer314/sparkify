# %% [markdown]
# ### Importing all the libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession

# %%
sc=pyspark.SparkContext(appName="maps_lazy_evaluation_example")

# %% [markdown]
# ***Reading with DataFrames***

# %%
sc.getConf().getAll()
# Out:
# [('spark.driver.port', '58897'),
#  ('spark.app.id', 'local-1657638632628'),
#  ('spark.driver.host', 'DESKTOP-16U8UI0'),
#  ('spark.app.startTime', '1657638630880'),
#  ('spark.rdd.compress', 'True'),
#  ('spark.serializer.objectStreamReset', '100'),
#  ('spark.master', 'local[*]'),
#  ('spark.submit.pyFiles', ''),
#  ('spark.executor.id', 'driver'),
#  ('spark.submit.deployMode', 'client'),
#  ('spark.app.name', 'maps_lazy_evaluation_example'),
#  ('spark.ui.showConsoleProgress', 'true')]

# %%
spark=SparkSession \
    .builder \
    .appName("first spark SQL example") \
    .getOrCreate()

# %%
# to get all the parameters of sparkContext
spark.sparkContext.getConf().getAll()
# Out:
# [('spark.driver.port', '58897'),
#  ('spark.app.id', 'local-1657638632628'),
#  ('spark.driver.host', 'DESKTOP-16U8UI0'),
#  ('spark.app.startTime', '1657638630880'),
#  ('spark.rdd.compress', 'True'),
#  ('spark.serializer.objectStreamReset', '100'),
#  ('spark.master', 'local[*]'),
#  ('spark.submit.pyFiles', ''),
#  ('spark.executor.id', 'driver'),
#  ('spark.submit.deployMode', 'client'),
#  ('spark.app.name', 'maps_lazy_evaluation_example'),
#  ('spark.ui.showConsoleProgress', 'true')]

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-16U8UI0:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>maps_lazy_evaluation_example</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# path="hdfs://ec2-34-218-86-174.us-west-2.compute.amazonaws.com:/9000/sparkify/sparkify_log_small.json
#
# 34-218-86-174 is the ip address of the master node

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data',
#  'DataWrangling.ipynb',
#  'programs',
#  'pyspark.txt',
#  'revise',
#  'sparkify_log_small.json',
#  'spark_archive']

# %%
path=r"data"
print(os.listdir(path))
pandas_df=pd.read_json(path+"\\sparkify_log_small.json", lines=True)
# Out:
# ['sparkify_log_small.json', 'test.csv']

# %%
pandas_df.head(n=1)
# Out:
#               ts userId  sessionId      page       auth method  status level  \
# 0  1513720872284   1046       5132  NextSong  Logged In    PUT     200  paid
#
#    itemInSession                           location  \
# 0            112  Charlotte-Concord-Gastonia, NC-SC
#
#                                            userAgent  lastName firstName  \
# 0  "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537....  Matthews   Kenneth
#
#    registration gender         artist                       song     length
# 0  1.509380e+12      M  Showaddywaddy  Christmas Tears Will Fall  232.93342

# %%
user_log=spark.read.json(path+"\\sparkify_log_small.json")
user_log.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
user_log.describe()
# Out:
# DataFrame[summary: string, artist: string, auth: string, firstName: string, gender: string, itemInSession: string, lastName: string, length: string, level: string, location: string, method: string, page: string, registration: string, sessionId: string, song: string, status: string, ts: string, userAgent: string, userId: string]

# %%
user_log.show(n=1)
# Out:
# +-------------+---------+---------+------+-------------+--------+---------+-----+--------------------+------+--------+-------------+---------+--------------------+------+-------------+--------------------+------+
# |       artist|     auth|firstName|gender|itemInSession|lastName|   length|level|            location|method|    page| registration|sessionId|                song|status|           ts|           userAgent|userId|
# +-------------+---------+---------+------+-------------+--------+---------+-----+--------------------+------+--------+-------------+---------+--------------------+------+-------------+--------------------+------+
# |Showaddywaddy|Logged In|  Kenneth|     M|          112|Matthews|232.93342| paid|Charlotte-Concord...|   PUT|NextSong|1509380319284|     5132|Christmas Tears W...|   200|1513720872284|"Mozilla/5.0 (Win...|  1046|
# ...

# %%
user_log.take(1)
# Out:
# [Row(artist='Showaddywaddy', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=112, lastName='Matthews', length=232.93342, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Christmas Tears Will Fall', status=200, ts=1513720872284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046')]

# %%
out_path=path+"\\sparkify_log_small.csv"

# %%
#writing to a csv file
user_log.write.save(out_path,format='csv',header=True)

# %%
user_log_2 = spark.read.csv(out_path, header=True)

# %%
user_log_2
# Out:
# DataFrame[artist: string, auth: string, firstName: string, gender: string, itemInSession: string, lastName: string, length: string, level: string, location: string, method: string, page: string, registration: string, sessionId: string, song: string, status: string, ts: string, userAgent: string, userId: string]

# %%
user_log_2.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: string (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: string (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: string (nullable = true)
#  |-- sessionId: string (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- ts: string (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
user_log_2.select("userId").show()
# Out:
# +------+
# |userId|
# +------+
# |  1046|
# |  1000|
# |  2219|
# |  2373|
# |  1747|
# |  1747|
# |  1162|
# |  1061|
# |   748|
# |   597|
# |  1806|
# |   748|
# |  1176|
# |  2164|
# |  2146|
# |  2219|
# |  1176|
# |  2904|
# |   597|
# |   226|
# +------+
# only showing top 20 rows

# %% [markdown]
# **Data Wrangling 2**

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import desc
from pyspark.sql.functions import asc
from pyspark.sql.functions import sum as Fsum


import datetime

# %matplotlib inline

# %%
spark = SparkSession \
    .builder \
    .appName("Wrangling Data") \
    .getOrCreate()

# %%
path = "data/sparkify_log_small.json"
user_log = spark.read.json(path)
user_log.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
user_log.describe("artist").show()
# Out:
# +-------+-----------------+
# |summary|           artist|
# +-------+-----------------+
# |  count|             8347|
# |   mean|            461.0|
# | stddev|            300.0|
# |    min|              !!!|
# |    max|ÃÂlafur Arnalds|
# +-------+-----------------+

# %%
user_log.describe("sessionId").show()
# Out:
# +-------+------------------+
# |summary|         sessionId|
# +-------+------------------+
# |  count|             10000|
# |   mean|         4436.7511|
# | stddev|2043.1281541827561|
# |    min|                 9|
# |    max|              7144|
# +-------+------------------+

# %%
#various options for the users loggedIn status 
user_log.select("page").dropDuplicates().sort("page").show()
# Out:
# +----------------+
# |            page|
# +----------------+
# |           About|
# |       Downgrade|
# |           Error|
# |            Help|
# |            Home|
# |           Login|
# |          Logout|
# |        NextSong|
# |   Save Settings|
# |        Settings|
# |Submit Downgrade|
# |  Submit Upgrade|
# |         Upgrade|
# +----------------+

# %%
# Event log of a user
user_log.select(["userId","firstname","page","song"]).where(user_log.userId=="1046").collect()
# Out:
# [Row(userId='1046', firstname='Kenneth', page='NextSong', song='Christmas Tears Will Fall'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Be Wary Of A Woman'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Public Enemy No.1'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Reign Of The Tyrants'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Father And Son'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='No. 5'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Seventeen'),
#  Row(userId='1046', firstname='Kenneth', page='Home', song=None),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='War on war'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Killermont Street'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Black & Blue'),
#  Row(userId='1046', firstname='Kenneth', page='Logout', song=None),
# ...

# %%
get_hour=udf(lambda x: datetime.datetime.fromtimestamp(x / 1000.0). hour)
user_log=user_log.withColumn("hour",get_hour(user_log.ts))
# At this time nothing happens because of the lazy evaluation of spark

# %%
user_log.head() # now spark will compute "hour" for head samples
# Out:
# Row(artist='Showaddywaddy', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=112, lastName='Matthews', length=232.93342, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Christmas Tears Will Fall', status=200, ts=1513720872284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', hour='17')

# %%
user_log.select("page").dropDuplicates().show()
# Out:
# +----------------+
# |            page|
# +----------------+
# |Submit Downgrade|
# |            Home|
# |       Downgrade|
# |          Logout|
# |   Save Settings|
# |           About|
# |        Settings|
# |           Login|
# |        NextSong|
# |            Help|
# |         Upgrade|
# |           Error|
# |  Submit Upgrade|
# +----------------+

# %%
songs_in_hour=user_log.filter(user_log.page=="NextSong").groupby(user_log.hour).count().orderBy(user_log.hour.cast('float'))

# %%
songs_in_hour.show()
# Out:
# +----+-----+
# |hour|count|
# +----+-----+
# |   0|  276|
# |   1|  348|
# |   2|  358|
# |   3|  375|
# |   4|  249|
# |   5|  216|
# |   6|  228|
# |   7|  251|
# |   8|  339|
# |   9|  462|
# |  10|  479|
# |  11|  484|
# |  12|  430|
# |  13|  362|
# |  14|  295|
# |  15|  257|
# |  16|  248|
# |  17|  369|
# |  18|  375|
# |  19|  456|
# +----+-----+
# only showing top 20 rows

# %%
songs_in_hour_pd=songs_in_hour.toPandas()

# %%
plt.scatter(songs_in_hour_pd["hour"],songs_in_hour_pd["count"])
plt.xlim(-1,24)
# Out:
# (-1.0, 24.0)

# %%
plt.scatter(songs_in_hour_pd["hour"], songs_in_hour_pd["count"])
plt.xlim(-1, 24);
plt.ylim(0, 1.2 * max(songs_in_hour_pd["count"]))
plt.xlabel("Hour")
plt.ylabel("Songs played");

# %%
user_log_valid = user_log.dropna(how = "any", subset = ["userId", "sessionId"])
user_log_valid.count()
# Out:
# 10000

# %%
user_log.select("userId").dropDuplicates().sort("userId").show()
# Out:
# +------+
# |userId|
# +------+
# |      |
# |    10|
# |   100|
# |  1000|
# |  1003|
# |  1005|
# |  1006|
# |  1017|
# |  1019|
# |  1020|
# |  1022|
# |  1025|
# |  1030|
# |  1035|
# |  1037|
# |   104|
# |  1040|
# |  1042|
# |  1043|
# |  1046|
# +------+
# only showing top 20 rows

# %%
user_log_valid = user_log_valid.filter(user_log_valid["userId"] != "")
user_log_valid.count()
# Out:
# 9664

# %%
user_log_valid.select("page").dropDuplicates().show()
# Out:
# +----------------+
# |            page|
# +----------------+
# |Submit Downgrade|
# |            Home|
# |       Downgrade|
# |          Logout|
# |   Save Settings|
# |           About|
# |        Settings|
# |        NextSong|
# |            Help|
# |         Upgrade|
# |           Error|
# |  Submit Upgrade|
# +----------------+

# %%
user_log_valid.filter(user_log_valid.page=="Submit Downgrade").show()
# Out:
# +------+---------+---------+------+-------------+--------+------+-----+--------------------+------+----------------+-------------+---------+----+------+-------------+--------------------+------+----+
# |artist|     auth|firstName|gender|itemInSession|lastName|length|level|            location|method|            page| registration|sessionId|song|status|           ts|           userAgent|userId|hour|
# +------+---------+---------+------+-------------+--------+------+-----+--------------------+------+----------------+-------------+---------+----+------+-------------+--------------------+------+----+
# |  null|Logged In|    Kelly|     F|           24|  Newton|  null| paid|Houston-The Woodl...|   PUT|Submit Downgrade|1513283366284|     5931|null|   307|1513768454284|Mozilla/5.0 (Wind...|  1138|   6|
# ...

# %%
user_log.select(["userId","firstname","page","level","song"]).where(user_log.userId=="1138").collect()
# Out:
# [Row(userId='1138', firstname='Kelly', page='Home', level='paid', song=None),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Everybody Everybody'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Gears'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Use Somebody'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Love Of My Life (1993 Digital Remaster)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Down In The Valley Woe'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Treat Her Like A Lady'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song="Everybody Thinks You're An Angel"),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Fourteen Wives'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Love On The Rocks'),
# ...

# %%
flag_downgrade_event = udf(lambda x: 1 if x == "Submit Downgrade" else 0, IntegerType())

# %%
user_log_valid = user_log_valid.withColumn("downgraded", flag_downgrade_event("page"))

# %%
user_log_valid.head()
# Out:
# Row(artist='Showaddywaddy', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=112, lastName='Matthews', length=232.93342, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Christmas Tears Will Fall', status=200, ts=1513720872284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', hour='17', downgraded=0)

# %%
from pyspark.sql import Window

# %%
windowval = Window.partitionBy("userId").orderBy(desc("ts")).rangeBetween(Window.unboundedPreceding, 0)

# %%
user_log_valid = user_log_valid.withColumn("phase", Fsum("downgraded").over(windowval))

# %%
user_log_valid.head()
# Out:
# Row(artist='Fabolous / The-Dream', auth='Logged In', firstName='Kevin', gender='M', itemInSession=1, lastName='Gilbert', length=231.54893, level='free', location='Shreveport-Bossier City, LA', method='PUT', page='NextSong', registration=1505550349284, sessionId=1435, song='Throw It In The Bag', status=200, ts=1513783259284, userAgent='Mozilla/5.0 (Windows NT 6.3; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='1436', hour='10', downgraded=0, phase=0)

# %%
user_log_valid.select(["userId", "firstname", "ts", "page", "level", "phase"]).where(user_log.userId == "1436").sort("ts").collect()
# Out:
# [Row(userId='1436', firstname='Kevin', ts=1513782858284, page='NextSong', level='free', phase=0),
#  Row(userId='1436', firstname='Kevin', ts=1513783259284, page='NextSong', level='free', phase=0)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Quiz

# %%
user_log.count()
# Out:
# 10000

# %%
user_log.filter(user_log.userId=="").show()
# Out:
# +------+----------+---------+------+-------------+--------+------+-----+--------+------+-----+------------+---------+----+------+-------------+---------+------+----+
# |artist|      auth|firstName|gender|itemInSession|lastName|length|level|location|method| page|registration|sessionId|song|status|           ts|userAgent|userId|hour|
# +------+----------+---------+------+-------------+--------+------+-----+--------+------+-----+------------+---------+----+------+-------------+---------+------+----+
# |  null|Logged Out|     null|  null|            0|    null|  null| free|    null|   PUT|Login|        null|     5598|null|   307|1513721196284|     null|      |  17|
# |  null|Logged Out|     null|  null|           26|    null|  null| paid|    null|   GET| Home|        null|      428|null|   200|1513721274284|     null|      |  17|
# ...

# %%
user_log.filter(user_log.userId=="").select("page").dropDuplicates().show()
# Out:
# +-----+
# | page|
# +-----+
# | Home|
# |About|
# |Login|
# | Help|
# +-----+

# %%
user_log.head()
# Out:
# Row(artist='Showaddywaddy', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=112, lastName='Matthews', length=232.93342, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Christmas Tears Will Fall', status=200, ts=1513720872284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', hour='17')

# %%
user_log.select(["userId"]).dropDuplicates().filter(user_log.gender=="F").count()
# Out:
# 462

# %%
artist_count=user_log.select(["artist"]).groupBy(user_log.artist).count()

# %%
artist_count.orderBy("count").tail(5)
# Out:
# [Row(artist='BjÃ\x83Â¶rk', count=46),
#  Row(artist='Florence + The Machine', count=52),
#  Row(artist='Kings Of Leon', count=69),
#  Row(artist='Coldplay', count=83),
#  Row(artist=None, count=1653)]

# %%
user_log.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)
#  |-- hour: string (nullable = true)

# %%
user_log.take(5)
# Out:
# [Row(artist='Showaddywaddy', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=112, lastName='Matthews', length=232.93342, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Christmas Tears Will Fall', status=200, ts=1513720872284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', hour='17'),
#  Row(artist='Lily Allen', auth='Logged In', firstName='Elizabeth', gender='F', itemInSession=7, lastName='Chase', length=195.23873, level='free', location='Shreveport-Bossier City, LA', method='PUT', page='NextSong', registration=1512718541284, sessionId=5027, song='Cheryl Tweedy', status=200, ts=1513720878284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1000', hour='17'),
# ...

# %%
user_log.select("page").dropDuplicates().show()
# Out:
# +----------------+
# |            page|
# +----------------+
# |Submit Downgrade|
# |            Home|
# |       Downgrade|
# |          Logout|
# |   Save Settings|
# |           About|
# |        Settings|
# |           Login|
# |        NextSong|
# |            Help|
# |         Upgrade|
# |           Error|
# |  Submit Upgrade|
# +----------------+

# %%
user_log.filter(user_log.page=="Home")

# %%
df=user_log

# %%
from pyspark.sql.functions import isnan, count, when, col, desc, udf, col, sort_array, asc, avg
from pyspark.sql.functions import sum as Fsum
from pyspark.sql.window import Window
from pyspark.sql.types import IntegerType

# %%
# TODO: filter out 0 sum and max sum to get more exact answer

function = udf(lambda ishome : int(ishome == 'Home'), IntegerType())

user_window = Window \
    .partitionBy('userID') \
    .orderBy(desc('ts')) \
    .rangeBetween(Window.unboundedPreceding, 0)

cusum = df.filter((df.page == 'NextSong') | (df.page == 'Home')) \
    .select('userID', 'page', 'ts') \
    .withColumn('homevisit', function(col('page'))) \
    .withColumn('period', Fsum('homevisit').over(user_window))

cusum.filter((cusum.page == 'NextSong')) \
    .groupBy('userID', 'period') \
    .agg({'period':'count'}) \
    .agg({'count(period)':'avg'}).show()
# Out:
# +------------------+
# |avg(count(period))|
# +------------------+
# | 6.898347107438017|
# +------------------+
